# %% [markdown]
# # quant sandbox: *Food Fight!*
# This notebook lets me play around with quantitative analysis of Altru output. Currently set up to take two files, one with program data and another with attendee data, and customized for the Food Fight program series.

# %% [markdown]
# ## Import statements, classes, and methods. Run these then keep going.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme()
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
import ipywidgets as widgets
import traitlets
from IPython.display import display
from tkinter import Tk, filedialog

# %%
class SelectFilesButton(widgets.Button):
    """A file widget that leverages tkinter.filedialog."""

    def __init__(self):
        super(SelectFilesButton, self).__init__()
        # Add the selected_files trait
        self.add_traits(files=traitlets.traitlets.List())
        # Create the button.
        self.description = "Select Files"
        self.icon = "square-o"
        self.style.button_color = "orange"
        # Set on click behavior.
        self.on_click(self.select_files)

    @staticmethod
    def select_files(b):
        """Generate instance of tkinter.filedialog.

        Parameters
        ----------
        b : obj:
            An instance of ipywidgets.widgets.Button 
        """
        # Create Tk root
        root = Tk()
        # Hide the main window
        root.withdraw()
        # Raise the root to the top of all windows.
        root.call('wm', 'attributes', '.', '-topmost', True)
        # List of selected fileswill be set to b.value
        b.files = filedialog.askopenfilename(multiple=True)

        b.description = "Files Selected"
        b.icon = "check-square-o"
        b.style.button_color = "lightgreen"

# %%
def convert_yesno_to_bool(yesno):
    """ This method converts 'yes' and 'no' in an Altru excel file to boolean values."""
    if yesno.casefold() == "yes".casefold():
        return True
    elif yesno.casefold() == "no".casefold():
        return False
    else:
        return np.nan

# %%
def clean_up_df(raw_df):
    """ 
    This method takes a dataframe with program information like Name, Location, Date, Time, Capacity, 
    and two rows for Attended, one with a number for 'Yes' and another with a number for 'No'
    """
    clean_df = pd.DataFrame(columns=('Name', 'Type', 'Location', 'Date', 'Time', 'Day', 
                                     'Capacity', 'Preregistered', 'Attended', 'Percentage'))
    clean_df['Name'] = raw_df['Name'].unique()
#     print(clean_df['Name'])
    for i in range(len(clean_df)):
        namemask = raw_df.where(raw_df['Name'] == clean_df['Name'][i])
        fvi = namemask.first_valid_index()
        clean_df['Location'][i] = namemask['Location'][fvi]
        clean_df['Date'][i] = pd.to_datetime(namemask['Date'][fvi])
        clean_df['Time'][i] = namemask['Time'][fvi]
        clean_df['Capacity'][i] = namemask['Capacity'][fvi]
        yes_fvi = namemask.where(namemask['Attended'] == "Yes").first_valid_index()
        if yes_fvi == None:
            clean_df['Attended'][i] = 0
        else:
            clean_df['Attended'][i] = namemask['Number'][yes_fvi]
        no_fvi = namemask.where(namemask['Attended'] == "No").first_valid_index()
        if no_fvi == None:
            clean_df['Preregistered'][i] = clean_df['Attended'][i]
        else:
            clean_df['Preregistered'][i] = clean_df['Attended'][i] + namemask['Number'][no_fvi]
                                                                                    
    clean_df['Percentage'] = clean_df['Attended'] / clean_df['Preregistered']
    clean_df.sort_values(by="Date", inplace=True)
    clean_df['Day'] = [j.strftime('%a') for j in clean_df['Date']]

    return clean_df

# %% [markdown]
# ## Run the cell below, then click the button to select your data file to load.

# %% [markdown]
# The code expects an .xlsx data file made in Altru with the 'Program Query: Food Fight!' ad-hoc query. This file makes columns for the program name, program location, program date and time, participant capacity as specified in Altru, number of spaces still available, then two rows for each program: one with the number of pre-registrants who attended, and one with the number of pre-registrants who did not.

# %%
# button1 = SelectFilesButton()
# button1  # This will display the button in the context of Jupyter Notebook

# %% [markdown]
# Run this next cell to assign that file name to a variable and read in the excel file, then make a Pandas Dataframe called `programs` with the cleaned data. It will print basic information about the `programs` dataframe.

# %%
# program_xlsx_file = button1.files[0]
program_xlsx_file = "./foodfight_program_query.xlsx"
raw_program_data = pd.read_excel(program_xlsx_file, engine='openpyxl')
programs = clean_up_df(raw_program_data)
print(programs.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29 entries, 11 to 3
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           29 non-null     object
#  1   Type           0 non-null      object
#  2   Location       29 non-null     object
#  3   Date           29 non-null     object
#  4   Time           29 non-null     object
#  5   Day            29 non-null     object
#  6   Capacity       29 non-null     object
#  7   Preregistered  29 non-null     object
#  8   Attended       29 non-null     object
#  9   Percentage     29 non-null     object
# dtypes: object(10)
# memory usage: 2.5+ KB
# None

# %% [markdown]
# In order to do analysis about workshops, conversations, and performances, we need to allocate the 'Type' of program based on keywords in the title. Change these if you need to, and make them specific as needed to get this to work right.

# %%
## Keywords to search for to allocate workshops, conversations, performances, and other not listed
workshops = ['workshop', 'ethnobotany', 'food landscape', 'farmers market']
conversations = ['intersection', 'conversation', 'discussion']
performances = ['screening', 'poetry slam', 'dancers and singers', 'performance']

for i in range(len(programs)):
    for keyword in workshops:
        if keyword.casefold() in programs['Name'][i].casefold():
            programs['Type'][i] = "Workshop"
    for keyword in conversations:
        if keyword.casefold() in programs['Name'][i].casefold():
            programs['Type'][i] = "Conversation"
    for keyword in performances:
        if keyword.casefold() in programs['Name'][i].casefold():
            programs['Type'][i] = "Performance"
    if "cancelled".casefold() in programs['Name'][i].casefold():
        programs['Type'][i] = "Other"
        programs['Percentage'][i] = np.nan
    elif "postponed".casefold() in programs['Name'][i].casefold():
        programs['Type'][i] = "Other"
        programs['Percentage'][i] = np.nan
#     w_idx = programs['Name'].str.casefold().str.contains("workshop".casefold())
#     programs['Type'][w_idx] = "Workshop"

type_cats = ['Workshop', 'Conversation', 'Performance', 'Other']
programs['Type'] = pd.Categorical(programs['Type'], categories=type_cats, ordered=True)
nan_idx = programs['Type'].isnull()
programs['Type'][nan_idx] = 'Other'
programs['Location'] = programs['Location'].replace("Beal Botanical Garden", "Beal")
# programs['Location'] = programs['Location'].replace("STEM Teaching and Learning Facility", "STEM")
display(programs.head(5))
# Out:
#                                         Name      Type              Location  \
# 11             Food Fight! Opening Reception     Other            MSU Museum
# 4         CANCELLED-Food Futures Performance     Other            MSU Museum
# 17             POSTPONED-Composting Workshop     Other  MSU Recycling Center
# 8   Ethnobotany On the Sphere: Chile Peppers  Workshop            MSU Museum
# 5        CANCELLED-Michigan's Food Landscape     Other            MSU Museum
#
#                    Date      Time  Day Capacity Preregistered Attended  \
# 11  2024-01-11 00:00:00   5:00 PM  Thu    500.0         290.0    173.0
# 4   2024-01-12 00:00:00  12:10 PM  Fri     60.0          15.0        0
# 17  2024-01-18 00:00:00   5:00 PM  Thu     48.0          48.0        0
# 8   2024-01-20 00:00:00   1:00 PM  Sat     65.0          60.0     36.0
# 5   2024-01-21 00:00:00   1:00 PM  Sun      2.0           2.0        0
#
#    Percentage
# 11   0.596552
# 4         NaN
# 17        NaN
# 8         0.6
# 5         NaN

# %% [markdown]
# If you have cancelled or postponed programs (or other reasons why the attendance percentage would be Not a Number), filter those out of what's going to be plotted.

# %%
nan_idx = programs['Percentage'].isnull()
programs = programs.loc[~nan_idx]

# %% [markdown]
# If the program series is ongoing, filter out the ones that haven't happened yet.

# %%
future_idx = programs['Date'] > pd.Timestamp.today()
programs = programs.loc[~future_idx]

# %% [markdown]
# ## Let's get some basic numbers!

# %% [markdown]
# How many people have attended *Food Fight!* programs so far?

# %%
programs['Attended'].sum()
# Out:
# 986.0

# %% [markdown]
# How many people have pre-registered for a *Food Fight!* program so far?

# %%
programs['Preregistered'].sum()
# Out:
# 1915.0

# %% [markdown]
# Plot the attendance of programs as a function of time!

# %%
fig, ax = plt.subplots(figsize=(8,5))
fig = sns.scatterplot(data=programs, x='Date', y='Percentage', hue='Type')
x_dates = pd.date_range(start='1/2024', end='6/2024', freq='MS', inclusive='both')
ax.set_xticks(x_dates, labels=x_dates.strftime('%b %Y'), horizontalalignment='left')
## TODO: mouseover to read name?!?
ax.set(ylim=(0, 0.65))
plt.show()

# %% [markdown]
# ## Program location

# %% [markdown]
# Rank the locations by number of programs held there.

# %%
loc_cats = programs['Location'].value_counts(ascending=False, dropna=True).index
programs['Location'] = pd.Categorical(programs['Location'], categories=loc_cats, ordered=True)

# %%
display(programs.groupby('Location', observed=False)['Percentage'].mean())
display(programs.groupby('Location', observed=False)['Percentage'].std())
# Out:
# Location
# MSU Museum     0.458278
# Beal           0.428183
# MSU Library    0.721854
# MSU Union      0.520833
# RCAH           0.580311
# Name: Percentage, dtype: object
# Location
# MSU Museum     0.113895
# Beal           0.098752
# MSU Library         NaN
# MSU Union           NaN
# RCAH                NaN
# Name: Percentage, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(8,5))
fig = sns.barplot(data=programs, x='Location', y='Percentage', saturation=1, alpha=0.75)
ax.set(xlabel=" ", ylabel="Percentage", title='Attendance by program location')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# It's worth noting that the Library and RCAH programs had very strong partnerships and co-sponsorships, which significantly boosted attendance.

# %% [markdown]
# ## Program type

# %%
display(programs.groupby('Type', observed=False)['Percentage'].mean())
display(programs.groupby('Type', observed=False)['Percentage'].std())
# Out:
# Type
# Workshop        0.432322
# Conversation     0.50623
# Performance     0.456193
# Other            0.59222
# Name: Percentage, dtype: object
# Type
# Workshop        0.109191
# Conversation    0.160038
# Performance     0.106659
# Other           0.026492
# Name: Percentage, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(8,5))
fig = sns.barplot(data=programs.sort_values('Type'), x='Type', y='Percentage', saturation=1, alpha=0.75)
ax.set(xlabel="", ylabel="Percentage", ylim=(0, 0.65), title='Attendance by program type')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# ## Time of day

# %%
display(programs.groupby('Time')['Percentage'].mean())
display(programs.groupby('Time')['Percentage'].std())
# Out:
# Time
# 12:00 PM     0.39493
# 1:00 PM       0.5194
# 5:00 PM     0.464943
# 7:00 PM     0.518971
# Name: Percentage, dtype: object
# Time
# 12:00 PM    0.092330
# 1:00 PM     0.107902
# 5:00 PM     0.186124
# 7:00 PM     0.114763
# Name: Percentage, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(8,5))
fig = sns.barplot(data=programs.sort_values('Time'), x='Time', y='Percentage', saturation=1, alpha=0.75)
ax.set(xlabel="Time of day", ylabel="Percentage", ylim=(0, 0.65), title='Attendance by program start time')
plt.show()

# %% [markdown]
# The 1pm programs were on weekends, so day of the week is also a factor.

# %% [markdown]
# ## Day of week

# %%
display(programs.groupby('Day', observed=False)['Percentage'].mean())
display(programs.groupby('Day', observed=False)['Percentage'].std())
# Out:
# Day
# Sat    0.519042
# Sun    0.520833
# Thu    0.508165
# Tue    0.384615
# Wed    0.396404
# Name: Percentage, dtype: object
# Day
# Sat    0.124591
# Sun         NaN
# Thu    0.120880
# Tue         NaN
# Wed    0.099627
# Name: Percentage, dtype: float64

# %%
days = ['Tue', 'Wed', 'Thu', 'Sat', 'Sun']
programs['Day'] = pd.Categorical(programs['Day'], categories=days, ordered=True)
fig, ax = plt.subplots(figsize=(8,5))
fig = sns.barplot(data=programs.sort_values('Day'), x='Day', y='Percentage', saturation=1, alpha=0.75)
ax.set(xlabel="Day of the week", ylabel="Percentage", ylim=(0, 0.65), title='Attendance by day of the week')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# Keep in mind that the Tuesday and Wednesday programs were lunchtime programs, and Thursday programs were in the evening, so time of day is at play here as well.

# %% [markdown]
# # Program attendees

# %% [markdown]
# Now we can get nitty-gritty. Let's load in the data file with all the registrants for each program.

# %%
# button2 = SelectFilesButton()
# button2  # This will display the button in the context of Jupyter Notebook

# %%
# reg_xlsx_file = button2.files[0]
reg_xlsx_file = "~/OneDrive - Michigan State University/attendance_data/altru_foodfight_program_attendees.xlsx"

# %%
registrants = pd.read_excel(reg_xlsx_file, engine='openpyxl', converters={'Attended': convert_yesno_to_bool})
registrants.rename(columns={"Name": "Visitor name",
                          "Registration Information\\Response": "MSU affiliation", 
                          "Program Events\\Name": "Program name", 
                          "Program Events\Capacity": "Program capacity",
                          "Program Events\\Locations\\Name": "Program location"},
                   inplace=True)
display(registrants.info())
registrants['Program location'].replace("Beal Botanical Garden", "Beal", inplace=True)
registrants['MSU affiliation'].replace("Faculty or Staff", "Faculty/Staff", inplace=True)  # Renaming this for consistency with Parent/Family
registrants['MSU affiliation'].fillna("N/A", inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1931 entries, 0 to 1930
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Visitor name      1931 non-null   object
#  1   Attended          1931 non-null   bool
#  2   Host name         1119 non-null   object
#  3   MSU affiliation   1325 non-null   object
#  4   Program name      1931 non-null   object
#  5   Program capacity  1931 non-null   int64
#  6   Program location  1931 non-null   object
#  7   QUERYRECID        1931 non-null   object
# dtypes: bool(1), int64(1), object(6)
# memory usage: 107.6+ KB
# None

# %%
print(registrants['MSU affiliation'])
# Out:
# 0                 N/A
# 1             Student
# 2             Not MSU
# 3       Faculty/Staff
# 4       Faculty/Staff
#             ...
# 1926          Student
# 1927          Student
# 1928              N/A
# 1929          Student
# 1930          Student
# Name: MSU affiliation, Length: 1931, dtype: object

# %%
## Only keep those with a location in the list of 
registrants = registrants[registrants['Program location'].isin(programs['Location'].unique().tolist())]
print(registrants['Program location'].unique())
# Out:
# ['MSU Museum' 'Beal' 'MSU Library' 'RCAH' 'MSU Union']

# %%
fig = sns.histplot(registrants, x='Program location', y='MSU affiliation')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## MSU affiliation

# %%
## TODO: group by visitor name, WORKING HERE
reg_by_name = pd.DataFrame(columns=('Visitor name', 'Attended', 'Preregistered', 'Percentage', 'Host name', 'MSU affiliation'))
reg_by_name['Visitor name'] = registrants['Visitor name'].unique()
for i in range(len(reg_by_name['Visitor name'])):
    reg_by_name['Preregistered'][i] = sum() # sum of times it appears in the whole registrants list.
    reg_by_name['Attended'][i] = #sum of attended where name == visitors name
    # do affiliation thing from hosts below, and a list of hosts? then percentage at the end, outside of the loop.
# Out:
# 1447
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1442    NaN
# 1443    NaN
# 1444    NaN
# 1445    NaN
# 1446    NaN
# Name: MSU affiliation, Length: 1447, dtype: object
#            Visitor name Attended  Preregistered Percentage Host name  \
# 0     A (child)  Strode      NaN            NaN        NaN       NaN
# 1        Aaliyah Brooks      NaN            NaN        NaN       NaN
# 2       Abbaigail Jones      NaN            NaN        NaN       NaN
# 3         Abbie Stevens      NaN            NaN        NaN       NaN
# 4        Abby  Anderson      NaN            NaN        NaN       NaN
# ...                 ...      ...            ...        ...       ...
# 1442        Zach Krause      NaN            NaN        NaN       NaN
# 1443         Zack Cohen      NaN            NaN        NaN       NaN
# 1444       Zay Reynolds      NaN            NaN        NaN       NaN
# 1445        Zaynah Arja      NaN            NaN        NaN       NaN
# 1446       Zoey  parish      NaN            NaN        NaN       NaN
#
#      MSU affiliation
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 1442             NaN
# 1443             NaN
# 1444             NaN
# 1445             NaN
# 1446             NaN
#
# [1447 rows x 6 columns]

# %% [markdown]
# Categorize and sort the attendance by MSU affiliation, and assign it to a new dataframe `affils`

# %%
affils = pd.DataFrame(columns=('MSU affiliation', 'Attended', 'Preregistered', 'Percentage'))
affils['MSU affiliation'] = ['Student', 'Faculty/Staff', 'Alum', 'Parent/Family', 'Not MSU', 'N/A']

for item in affils['MSU affiliation']:
    affils['Attended'][affils['MSU affiliation'] == item] = sum(registrants['MSU affiliation'][registrants['Attended']] == item)
    affils['Preregistered'][affils['MSU affiliation'] == item] = sum(registrants['MSU affiliation'] == item)
    
# affils['Attended'][affils['MSU affiliation'] == 'N/A'] = len(registrants['MSU affiliation'][registrants['Attended']]) - sum(registrants['MSU affiliation'][registrants['Attended']].notnull())
# affils['Preregistered'][affils['MSU affiliation'] == 'N/A'] = len(registrants['MSU affiliation']) - sum(registrants['MSU affiliation'].notnull())
affils['Percentage'] = affils['Attended'] / affils['Preregistered']
display(affils)
# Out:
# Student
# Faculty/Staff
# Alum
# Parent/Family
# Not MSU
# N/A
#   MSU affiliation Attended Preregistered Percentage
# 0         Student      223           355   0.628169
# 1   Faculty/Staff      168           321   0.523364
# 2            Alum       85           198   0.429293
# 3   Parent/Family       47           109   0.431193
# 4         Not MSU      108           326   0.331288
# 5             N/A      276           551   0.500907

# %%
fig, ax = plt.subplots(figsize=(8,5))
fig = sns.barplot(data=affils, x='MSU affiliation', y='Preregistered', saturation=1, alpha=0.75)
ax.set(xlabel="", ylabel="Number of people", title='Program pre-registration by MSU affiliation')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))
fig = sns.barplot(data=affils, x='MSU affiliation', y='Percentage', saturation=1, alpha=0.75)
ax.set(xlabel="", ylabel="Percentage", ylim=(0, 0.65), title='Attendance percentage by MSU affiliation')
plt.show()

# %% [markdown]
# ## Hosts

# %%
hosts = pd.DataFrame(columns=('Name', 'Attended', 'Preregistered', 'Percentage', 'MSU affiliation'))
hosts['Name'] = registrants['Host name'][registrants['Host name'].notnull()].unique()
for i in range(len(hosts)):
    h = registrants['Visitor name'] == hosts['Name'][i]
    t1 = registrants['MSU affiliation'][h & registrants['MSU affiliation'][h].notnull()].unique()
#     print(t1)
    if len(t1) > 1 and "N/A" in t1:
        hosts['MSU affiliation'][i] = np.delete(t1, np.where(t1 == 'N/A'))[0]
    else:
        hosts['MSU affiliation'][i] = t1[0]
#     print("\t ", hosts['MSU affiliation'][i])
    t2 = registrants['Attended'][h]
    hosts['Attended'][i] = sum(registrants['Attended'][h])
    hosts['Preregistered'][i] = sum(h)
hosts['Percentage'] = hosts['Attended'] / hosts['Preregistered']
display(hosts)
# Out:
#                     Name Attended Preregistered Percentage MSU affiliation
# 0           Cirea Strode        1             1        1.0             N/A
# 1    Museum CoLab Studio        0            15        0.0             N/A
# 2             Sarah Doty        0             1        0.0         Not MSU
# 3         Abby  Anderson        0             1        0.0         Student
# 4        Jessica Clauser        1             1        1.0         Student
# ..                   ...      ...           ...        ...             ...
# 335           Robin Izon        0             1        0.0   Faculty/Staff
# 336         Olivia Smith        1             1        1.0         Student
# 337         Rahimin Khan        0             1        0.0         Student
# 338  Rocío Quispe-Agnoli        0             1        0.0   Faculty/Staff
# 339         Sherry Early        0             1        0.0            Alum
#
# [340 rows x 5 columns]

# %%
hosts['MSU affiliation'] = pd.Categorical(hosts['MSU affiliation'], categories=affils['MSU affiliation'], ordered=True)
fig, ax = plt.subplots(figsize=(8,5))
fig = sns.histplot(data=hosts.sort_values('MSU affiliation'), x='MSU affiliation', hue='MSU affiliation', legend=False)
ax.set(xlabel="", ylabel="Number of people", title='People who registered guests by MSU affiliation')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(

# %%
fig, ax = plt.subplots(figsize=(8,5))
fig = sns.barplot(data=hosts.sort_values('MSU affiliation'), x='MSU affiliation', y='Percentage', saturation=1, alpha=0.75)
ax.set(xlabel="", ylabel="Percentage", ylim=(0, 0.65), title='Host attendance percentage by MSU affiliation')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
